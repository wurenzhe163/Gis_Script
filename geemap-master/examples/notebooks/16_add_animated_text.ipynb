# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/16_add_animated_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
import geemap
import os

# %%
geemap.show_youtube('fDnDVuM_Ke4')
# Out:
# Output(layout=Layout(width='815px'))

# %% [markdown]
# ## Update the geemap package
#
# If you run into errors with this notebook, please uncomment the line below to update the [geemap](https://github.com/giswqs/geemap#installation) package to the latest version from GitHub.
# Restart the Kernel (Menu -> Kernel -> Restart) to take effect.

# %%
# geemap.update_package()

# %% [markdown]
# ## Add animated text to an existing GIF
#
# You can download this GIF example from [here](https://github.com/giswqs/geemap/blob/master/examples/data/animation.gif). You can also create GIF images from Earth Engine data using this amazing [LT-GEE Time Series Animator](https://emaprlab.users.earthengine.app/view/lt-gee-time-series-animator), which was created by [Justin Braaten](https://github.com/jdbcode).

# %%
in_gif
# Out:
# 'C:\\Users\\SAR\\Desktop\\gitclone\\geemap-master\\examples\\data\\animation.gif'

# %%
in_gif = os.path.abspath('../data/animation.gif')
out_dir = os.path.join(os.path.expanduser('~'), 'Downloads')
out_gif = os.path.join(out_dir, 'output.gif')
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
geemap.show_image(in_gif)
# Out:
# Output()

# %% [markdown]
# ### Add animated text to GIF

# %%
geemap.add_text_to_gif(
    in_gif,
    out_gif,
    xy=('5%', '5%'),
    text_sequence=1984,
    font_size=30,
    font_color='#0000ff',
    duration=100,
)

# %%
geemap.show_image(out_gif)
# Out:
# Output()

# %% [markdown]
# ### Add place name

# %%
geemap.add_text_to_gif(
    out_gif, out_gif, xy=('30%', '85%'), text_sequence="Las Vegas", font_color='black'
)

# %%
geemap.show_image(out_gif)
# Out:
# Output()

# %% [markdown]
# ### Change font type

# %%
geemap.system_fonts()
# Out:
# ['ACaslonPro-Bold.otf',
#  'ACaslonPro-Bold.otf',
#  'ACaslonPro-BoldItalic.otf',
#  'ACaslonPro-BoldItalic.otf',
#  'ACaslonPro-Regular.otf',
#  'ACaslonPro-Regular.otf',
#  'AGENCYB.TTF',
#  'AGENCYB.TTF',
#  'AGENCYR.TTF',
#  'AGENCYR.TTF',
#  'AGaramondPro-Bold.otf',
#  'AGaramondPro-Bold.otf',
#  'AGaramondPro-BoldItalic.otf',
#  'AGaramondPro-BoldItalic.otf',
#  'AGaramondPro-Regular.otf',
#  'AGaramondPro-Regular.otf',
#  'ALGER.TTF',
#  'ALGER.TTF',
#  'ANTQUAB.TTF',
#  'ANTQUAB.TTF',
#  'ANTQUABI.TTF',
#  'ANTQUABI.TTF',
#  'ANTQUAI.TTF',
#  'ANTQUAI.TTF',
#  'ARIALN.TTF',
#  'ARIALN.TTF',
#  'ARIALNB.TTF',
#  'ARIALNB.TTF',
#  'ARIALNBI.TTF',
#  'ARIALNBI.TTF',
#  'ARIALNI.TTF',
#  'ARIALNI.TTF',
#  'ARLRDBD.TTF',
#  'ARLRDBD.TTF',
#  'AdobeArabic-Regular.otf',
#  'AdobeArabic-Regular.otf',
#  'AdobeDevanagari-Bold.otf',
#  'AdobeDevanagari-BoldItalic.otf',
#  'AdobeDevanagari-Italic.otf',
#  'AdobeDevanagari-Regular.otf',
#  'AdobeFangsongStd-Regular.otf',
#  'AdobeFangsongStd-Regular.otf',
#  'AdobeGothicStd-Bold.otf',
#  'AdobeGothicStd-Bold.otf',
#  'AdobeGurmukhi-Regular.otf',
#  'AdobeGurmukhi-Regular.otf',
#  'AdobeHebrew-Regular.otf',
#  'AdobeHebrew-Regular.otf',
#  'AdobeMyungjoStd-Medium.otf',
#  'AdobeMyungjoStd-Medium.otf',
#  'AdobeNaskh-Medium.otf',
#  'AdobeNaskh-Medium.otf',
#  'BASKVILL.TTF',
#  'BASKVILL.TTF',
#  'BAUHS93.TTF',
#  'BAUHS93.TTF',
#  'BELL.TTF',
#  'BELL.TTF',
#  'BELLB.TTF',
#  'BELLB.TTF',
#  'BELLI.TTF',
#  'BELLI.TTF',
#  'BERNHC.TTF',
#  'BERNHC.TTF',
#  'BKANT.TTF',
#  'BKANT.TTF',
#  'BOD_B.TTF',
#  'BOD_B.TTF',
#  'BOD_BI.TTF',
#  'BOD_BI.TTF',
#  'BOD_BLAI.TTF',
#  'BOD_BLAI.TTF',
#  'BOD_BLAR.TTF',
#  'BOD_BLAR.TTF',
#  'BOD_CB.TTF',
#  'BOD_CB.TTF',
#  'BOD_CBI.TTF',
#  'BOD_CBI.TTF',
#  'BOD_CI.TTF',
#  'BOD_CI.TTF',
#  'BOD_CR.TTF',
#  'BOD_CR.TTF',
#  'BOD_I.TTF',
#  'BOD_I.TTF',
#  'BOD_PSTC.TTF',
#  'BOD_PSTC.TTF',
#  'BOD_R.TTF',
#  'BOD_R.TTF',
#  'BOOKOS.TTF',
#  'BOOKOS.TTF',
#  'BOOKOSB.TTF',
#  'BOOKOSB.TTF',
#  'BOOKOSBI.TTF',
#  'BOOKOSBI.TTF',
#  'BOOKOSI.TTF',
#  'BOOKOSI.TTF',
#  'BRADHITC.TTF',
#  'BRADHITC.TTF',
#  'BRITANIC.TTF',
#  'BRITANIC.TTF',
#  'BRLNSB.TTF',
#  'BRLNSB.TTF',
#  'BRLNSDB.TTF',
#  'BRLNSDB.TTF',
#  'BRLNSR.TTF',
#  'BRLNSR.TTF',
#  'BROADW.TTF',
#  'BROADW.TTF',
#  'BRUSHSCI.TTF',
#  'BRUSHSCI.TTF',
#  'BSSYM7.TTF',
#  'BSSYM7.TTF',
#  'CALIFB.TTF',
#  'CALIFB.TTF',
#  'CALIFI.TTF',
#  'CALIFI.TTF',
#  'CALIFR.TTF',
#  'CALIFR.TTF',
#  'CALIST.TTF',
#  'CALIST.TTF',
#  'CALISTB.TTF',
#  'CALISTB.TTF',
#  'CALISTBI.TTF',
#  'CALISTBI.TTF',
#  'CALISTI.TTF',
#  'CALISTI.TTF',
#  'CASTELAR.TTF',
#  'CASTELAR.TTF',
#  'CENSCBK.TTF',
#  'CENSCBK.TTF',
#  'CENTAUR.TTF',
#  'CENTAUR.TTF',
#  'CENTURY.TTF',
#  'CENTURY.TTF',
#  'CHILLER.TTF',
#  'CHILLER.TTF',
#  'COLONNA.TTF',
#  'COLONNA.TTF',
#  'COOPBL.TTF',
#  'COOPBL.TTF',
#  'COPRGTB.TTF',
#  'COPRGTB.TTF',
#  'COPRGTL.TTF',
#  'COPRGTL.TTF',
#  'CURLZ___.TTF',
#  'CURLZ___.TTF',
#  'Candara.ttf',
#  'Candara.ttf',
#  'Candarab.ttf',
#  'Candarab.ttf',
#  'Candarai.ttf',
#  'Candarai.ttf',
#  'Candaral.ttf',
#  'Candaral.ttf',
#  'Candarali.ttf',
#  'Candarali.ttf',
#  'Candaraz.ttf',
#  'Candaraz.ttf',
#  'DUBAI-BOLD.TTF',
#  'DUBAI-BOLD.TTF',
#  'DUBAI-LIGHT.TTF',
#  'DUBAI-LIGHT.TTF',
#  'DUBAI-MEDIUM.TTF',
#  'DUBAI-MEDIUM.TTF',
#  'DUBAI-REGULAR.TTF',
#  'DUBAI-REGULAR.TTF',
#  'DejaVuSans.ttf',
#  'Deng.ttf',
#  'Deng.ttf',
#  'Dengb.ttf',
#  'Dengb.ttf',
#  'Dengl.ttf',
#  'Dengl.ttf',
#  'ELEPHNT.TTF',
#  'ELEPHNT.TTF',
#  'ELEPHNTI.TTF',
#  'ELEPHNTI.TTF',
#  'ENGR.TTF',
#  'ENGR.TTF',
#  'ERASBD.TTF',
#  'ERASBD.TTF',
#  'ERASDEMI.TTF',
#  'ERASDEMI.TTF',
#  'ERASLGHT.TTF',
#  'ERASLGHT.TTF',
#  'ERASMD.TTF',
#  'ERASMD.TTF',
#  'FELIXTI.TTF',
#  'FELIXTI.TTF',
#  'FORTE.TTF',
#  'FORTE.TTF',
#  'FRABK.TTF',
#  'FRABK.TTF',
#  'FRABKIT.TTF',
#  'FRABKIT.TTF',
#  'FRADM.TTF',
#  'FRADM.TTF',
#  'FRADMCN.TTF',
#  'FRADMCN.TTF',
#  'FRADMIT.TTF',
#  'FRADMIT.TTF',
#  'FRAHV.TTF',
#  'FRAHV.TTF',
#  'FRAHVIT.TTF',
#  'FRAHVIT.TTF',
#  'FRAMDCN.TTF',
#  'FRAMDCN.TTF',
#  'FREESCPT.TTF',
#  'FREESCPT.TTF',
#  'FRSCRIPT.TTF',
#  'FRSCRIPT.TTF',
#  'FTLTLT.TTF',
#  'FTLTLT.TTF',
#  'FZSTK.TTF',
#  'FZSTK.TTF',
#  'FZYTK.TTF',
#  'FZYTK.TTF',
#  'Fences.ttf',
#  'Fences.ttf',
#  'GARA.TTF',
#  'GARA.TTF',
#  'GARABD.TTF',
#  'GARABD.TTF',
#  'GARAIT.TTF',
#  'GARAIT.TTF',
#  'GIGI.TTF',
#  'GIGI.TTF',
#  'GILBI___.TTF',
#  'GILBI___.TTF',
#  'GILB____.TTF',
#  'GILB____.TTF',
#  'GILC____.TTF',
#  'GILC____.TTF',
#  'GILI____.TTF',
#  'GILI____.TTF',
#  'GILLUBCD.TTF',
#  'GILLUBCD.TTF',
#  'GILSANUB.TTF',
#  'GILSANUB.TTF',
#  'GIL_____.TTF',
#  'GIL_____.TTF',
#  'GLECB.TTF',
#  'GLECB.TTF',
#  'GLSNECB.TTF',
#  'GLSNECB.TTF',
#  'GOTHIC.TTF',
#  'GOTHIC.TTF',
#  'GOTHICB.TTF',
#  'GOTHICB.TTF',
#  'GOTHICBI.TTF',
#  'GOTHICBI.TTF',
#  'GOTHICI.TTF',
#  'GOTHICI.TTF',
#  'GOUDOS.TTF',
#  'GOUDOS.TTF',
#  'GOUDOSB.TTF',
#  'GOUDOSB.TTF',
#  'GOUDOSI.TTF',
#  'GOUDOSI.TTF',
#  'GOUDYSTO.TTF',
#  'GOUDYSTO.TTF',
#  'Gabriola.ttf',
#  'Gabriola.ttf',
#  'HARLOWSI.TTF',
#  'HARLOWSI.TTF',
#  'HARNGTON.TTF',
#  'HARNGTON.TTF',
#  'HATTEN.TTF',
#  'HATTEN.TTF',
#  'HTOWERT.TTF',
#  'HTOWERT.TTF',
#  'HTOWERTI.TTF',
#  'HTOWERTI.TTF',
#  'IMPRISHA.TTF',
#  'IMPRISHA.TTF',
#  'INFROMAN.TTF',
#  'INFROMAN.TTF',
#  'ITCBLKAD.TTF',
#  'ITCBLKAD.TTF',
#  'ITCEDSCR.TTF',
#  'ITCEDSCR.TTF',
#  'ITCKRIST.TTF',
#  'ITCKRIST.TTF',
#  'Inkfree.ttf',
#  'Inkfree.ttf',
#  'JOKERMAN.TTF',
#  'JOKERMAN.TTF',
#  'JUICE___.TTF',
#  'JUICE___.TTF',
#  'KUNSTLER.TTF',
#  'KUNSTLER.TTF',
#  'LATINWD.TTF',
#  'LATINWD.TTF',
#  'LBRITE.TTF',
#  'LBRITE.TTF',
#  'LBRITED.TTF',
#  'LBRITED.TTF',
#  'LBRITEDI.TTF',
#  'LBRITEDI.TTF',
#  'LCALLIG.TTF',
#  'LCALLIG.TTF',
#  'LEELAWAD.TTF',
#  'LEELAWAD.TTF',
#  'LEELAWDB.TTF',
#  'LEELAWDB.TTF',
#  'LFAX.TTF',
#  'LFAX.TTF',
#  'LFAXD.TTF',
#  'LFAXD.TTF',
#  'LFAXDI.TTF',
#  'LFAXDI.TTF',
#  'LFAXI.TTF',
#  'LFAXI.TTF',
#  'LHANDW.TTF',
#  'LHANDW.TTF',
#  'LSANSD.TTF',
#  'LSANSD.TTF',
#  'LSANSDI.TTF',
#  'LSANSDI.TTF',
#  'LSANSI.TTF',
#  'LSANSI.TTF',
#  'LTYPEB.TTF',
#  'LTYPEB.TTF',
#  'LTYPEBO.TTF',
#  'LTYPEBO.TTF',
#  'LTYPEO.TTF',
#  'LTYPEO.TTF',
#  'LeelUIsl.ttf',
#  'LeelUIsl.ttf',
#  'LeelaUIb.ttf',
#  'LeelaUIb.ttf',
#  'LeelawUI.ttf',
#  'LeelawUI.ttf',
#  'LucidaBrightItalic.ttf',
#  'LucidaBrightItalic.ttf',
#  'LucidaBrightRegular.ttf',
#  'LucidaSansDemiBold.ttf',
#  'LucidaSansRegular.ttf',
#  'LucidaSansRegular.ttf',
#  'LucidaTypewriterRegular.ttf',
#  'MAGNETOB.TTF',
#  'MAGNETOB.TTF',
#  'MAIAN.TTF',
#  'MAIAN.TTF',
#  'MATURASC.TTF',
#  'MATURASC.TTF',
#  'MISTRAL.TTF',
#  'MISTRAL.TTF',
#  'MOD20.TTF',
#  'MOD20.TTF',
#  'MSUIGHUB.TTF',
#  'MSUIGHUB.TTF',
#  'MSUIGHUR.TTF',
#  'MSUIGHUR.TTF',
#  'MTCORSVA.TTF',
#  'MTCORSVA.TTF',
#  'MTExtra.ttf',
#  'MTExtra.ttf',
#  'Mt Extra Tiger.ttf',
#  'Mt Extra Tiger_01.ttf',
#  'Mt Extra Tiger_02.ttf',
#  'Mt Extra Tiger_02.ttf',
#  'NIAGENG.TTF',
#  'NIAGENG.TTF',
#  'NIAGSOL.TTF',
#  'NIAGSOL.TTF',
#  'Nirmala.ttf',
#  'Nirmala.ttf',
#  'NirmalaB.ttf',
#  'NirmalaB.ttf',
#  'NirmalaS.ttf',
#  'NirmalaS.ttf',
#  'NumberOnly.ttf',
#  'NumberOnly.ttf',
#  'OCRAEXT.TTF',
#  'OCRAEXT.TTF',
#  'OLDENGL.TTF',
#  'OLDENGL.TTF',
#  'ONYX.TTF',
#  'ONYX.TTF',
#  'OUTLOOK.TTF',
#  'OUTLOOK.TTF',
#  'Origin.ttf',
#  'Origin.ttf',
#  'PALSCRI.TTF',
#  'PALSCRI.TTF',
#  'PAPYRUS.TTF',
#  'PAPYRUS.TTF',
#  'PARCHM.TTF',
#  'PARCHM.TTF',
#  'PERBI___.TTF',
#  'PERBI___.TTF',
#  'PERB____.TTF',
#  'PERB____.TTF',
#  'PERI____.TTF',
#  'PERI____.TTF',
#  'PERTIBD.TTF',
#  'PERTIBD.TTF',
#  'PERTILI.TTF',
#  'PERTILI.TTF',
#  'PER_____.TTF',
#  'PER_____.TTF',
#  'PLAYBILL.TTF',
#  'PLAYBILL.TTF',
#  'POORICH.TTF',
#  'POORICH.TTF',
#  'PRISTINA.TTF',
#  'PRISTINA.TTF',
#  'RAGE.TTF',
#  'RAGE.TTF',
#  'RAVIE.TTF',
#  'RAVIE.TTF',
#  'REFSAN.TTF',
#  'REFSAN.TTF',
#  'REFSPCL.TTF',
#  'REFSPCL.TTF',
#  'ROCCB___.TTF',
#  'ROCCB___.TTF',
#  'ROCC____.TTF',
#  'ROCC____.TTF',
#  'ROCK.TTF',
#  'ROCK.TTF',
#  'ROCKB.TTF',
#  'ROCKB.TTF',
#  'ROCKBI.TTF',
#  'ROCKBI.TTF',
#  'ROCKEB.TTF',
#  'ROCKEB.TTF',
#  'ROCKI.TTF',
#  'ROCKI.TTF',
#  'SCHLBKB.TTF',
#  'SCHLBKB.TTF',
#  'SCHLBKBI.TTF',
#  'SCHLBKBI.TTF',
#  'SCHLBKI.TTF',
#  'SCHLBKI.TTF',
#  'SCRIPTBL.TTF',
#  'SCRIPTBL.TTF',
#  'SHOWG.TTF',
#  'SHOWG.TTF',
#  'SIMLI.TTF',
#  'SIMLI.TTF',
#  'SIMYOU.TTF',
#  'SIMYOU.TTF',
#  'SNAP____.TTF',
#  'SNAP____.TTF',
#  'STCAIYUN.TTF',
#  'STCAIYUN.TTF',
#  'STENCIL.TTF',
#  'STENCIL.TTF',
#  'STFANGSO.TTF',
#  'STFANGSO.TTF',
#  'STHUPO.TTF',
#  'STHUPO.TTF',
#  'STKAITI.TTF',
#  'STKAITI.TTF',
#  'STLITI.TTF',
#  'STLITI.TTF',
#  'STSONG.TTF',
#  'STSONG.TTF',
#  'STXIHEI.TTF',
#  'STXIHEI.TTF',
#  'STXINGKA.TTF',
#  'STXINGKA.TTF',
#  'STXINWEI.TTF',
#  'STXINWEI.TTF',
#  'STZHONGS.TTF',
#  'STZHONGS.TTF',
#  'Sitka.ttc',
#  'Sitka.ttc',
#  'SitkaB.ttc',
#  'SitkaB.ttc',
#  'SitkaI.ttc',
#  'SitkaI.ttc',
#  'SitkaZ.ttc',
#  'SitkaZ.ttc',
#  'Symbol Tiger Expert.ttf',
#  'Symbol Tiger Expert_01.ttf',
#  'Symbol Tiger Expert_02.ttf',
#  'Symbol Tiger Expert_02.ttf',
#  'Symbol Tiger.ttf',
#  'Symbol Tiger_01.ttf',
#  'Symbol Tiger_02.ttf',
#  'Symbol Tiger_02.ttf',
#  'TCBI____.TTF',
#  'TCBI____.TTF',
#  'TCB_____.TTF',
#  'TCB_____.TTF',
#  'TCCB____.TTF',
#  'TCCB____.TTF',
#  'TCCEB.TTF',
#  'TCCEB.TTF',
#  'TCCM____.TTF',
#  'TCCM____.TTF',
#  'TCMI____.TTF',
#  'TCMI____.TTF',
#  'TCM_____.TTF',
#  'TCM_____.TTF',
#  'TEMPSITC.TTF',
#  'TEMPSITC.TTF',
#  'Tiger Expert.ttf',
#  'Tiger Expert_01.ttf',
#  'Tiger Expert_02.ttf',
#  'Tiger Expert_02.ttf',
#  'Tiger.ttf',
#  'Tiger_01.ttf',
#  'Tiger_02.ttf',
#  'Tiger_02.ttf',
#  'VINERITC.TTF',
#  'VINERITC.TTF',
#  'VIVALDII.TTF',
#  'VIVALDII.TTF',
#  'VLADIMIR.TTF',
#  'VLADIMIR.TTF',
#  'WINGDNG2.TTF',
#  'WINGDNG2.TTF',
#  'WINGDNG3.TTF',
#  'WINGDNG3.TTF',
#  'YuGothB.ttc',
#  'YuGothB.ttc',
#  'YuGothL.ttc',
#  'YuGothL.ttc',
#  'YuGothM.ttc',
#  'YuGothM.ttc',
#  'YuGothR.ttc',
#  'YuGothR.ttc',
#  'ZWAdobeF.TTF',
#  'ZWAdobeF.TTF',
#  'arial.ttf',
#  'arial.ttf',
#  'arialbd.ttf',
#  'arialbd.ttf',
#  'arialbi.ttf',
#  'arialbi.ttf',
#  'ariali.ttf',
#  'ariali.ttf',
#  'ariblk.ttf',
#  'ariblk.ttf',
#  'bahnschrift.ttf',
#  'bahnschrift.ttf',
#  'calibri.ttf',
#  'calibri.ttf',
#  'calibrib.ttf',
#  'calibrib.ttf',
#  'calibrii.ttf',
#  'calibrii.ttf',
#  'calibril.ttf',
#  'calibril.ttf',
#  'calibrili.ttf',
#  'calibrili.ttf',
#  'calibriz.ttf',
#  'calibriz.ttf',
#  'cambria.ttc',
#  'cambria.ttc',
#  'cambriab.ttf',
#  'cambriab.ttf',
#  'cambriai.ttf',
#  'cambriai.ttf',
#  'cambriaz.ttf',
#  'cambriaz.ttf',
#  'comic.ttf',
#  'comic.ttf',
#  'comicbd.ttf',
#  'comicbd.ttf',
#  'comici.ttf',
#  'comici.ttf',
#  'comicz.ttf',
#  'comicz.ttf',
#  'consola.ttf',
#  'consola.ttf',
#  'consolab.ttf',
#  'consolab.ttf',
#  'consolai.ttf',
#  'consolai.ttf',
#  'consolaz.ttf',
#  'consolaz.ttf',
#  'constan.ttf',
#  'constan.ttf',
#  'constanb.ttf',
#  'constanb.ttf',
#  'constani.ttf',
#  'constani.ttf',
#  'constanz.ttf',
#  'constanz.ttf',
#  'corbel.ttf',
#  'corbel.ttf',
#  'corbelb.ttf',
#  'corbelb.ttf',
#  'corbeli.ttf',
#  'corbeli.ttf',
#  'corbell.ttf',
#  'corbell.ttf',
#  'corbelli.ttf',
#  'corbelli.ttf',
#  'corbelz.ttf',
#  'corbelz.ttf',
#  'cour.ttf',
#  'cour.ttf',
#  'courbd.ttf',
#  'courbd.ttf',
#  'courbi.ttf',
#  'courbi.ttf',
#  'couri.ttf',
#  'couri.ttf',
#  'ebrima.ttf',
#  'ebrima.ttf',
#  'ebrimabd.ttf',
#  'ebrimabd.ttf',
#  'envisym_.ttf',
#  'esri_1.ttf',
#  'esri_1.ttf',
#  'esri_105.ttf',
#  'esri_105.ttf',
#  'esri_11.ttf',
#  'esri_11.ttf',
#  'esri_12.ttf',
#  'esri_12.ttf',
#  'esri_121.ttf',
#  'esri_121.ttf',
#  'esri_13.ttf',
#  'esri_13.ttf',
#  'esri_130.ttf',
#  'esri_130.ttf',
#  'esri_131.ttf',
#  'esri_131.ttf',
#  'esri_132.ttf',
#  'esri_132.ttf',
#  'esri_133.ttf',
#  'esri_133.ttf',
#  'esri_14.ttf',
#  'esri_14.ttf',
#  'esri_144.ttf',
#  'esri_144.ttf',
#  'esri_149.ttf',
#  'esri_149.ttf',
#  'esri_15.ttf',
#  'esri_15.ttf',
#  'esri_150.ttf',
#  'esri_150.ttf',
#  'esri_151.ttf',
#  'esri_151.ttf',
#  'esri_152.ttf',
#  'esri_152.ttf',
#  'esri_153.ttf',
#  'esri_153.ttf',
#  'esri_159.ttf',
#  'esri_159.ttf',
#  'esri_16.ttf',
#  'esri_16.ttf',
#  'esri_160.ttf',
#  'esri_160.ttf',
#  'esri_161.ttf',
#  'esri_161.ttf',
#  'esri_17.ttf',
#  'esri_17.ttf',
#  'esri_19.ttf',
#  'esri_19.ttf',
#  'esri_2.ttf',
#  'esri_2.ttf',
#  'esri_20.ttf',
#  'esri_20.ttf',
#  'esri_21.ttf',
#  'esri_21.ttf',
#  'esri_216.ttf',
#  'esri_216.ttf',
#  'esri_22.ttf',
#  'esri_22.ttf',
#  'esri_220.ttf',
#  'esri_220.ttf',
#  'esri_221.ttf',
#  'esri_221.ttf',
#  'esri_222.ttf',
#  'esri_222.ttf',
#  'esri_223.ttf',
#  'esri_223.ttf',
#  'esri_224.ttf',
#  'esri_224.ttf',
#  'esri_225.ttf',
#  'esri_225.ttf',
#  'esri_23.ttf',
#  'esri_23.ttf',
#  'esri_24.ttf',
#  'esri_24.ttf',
#  'esri_25.ttf',
#  'esri_25.ttf',
#  'esri_26.ttf',
#  'esri_26.ttf',
#  'esri_27Mcr_2.ttf',
#  'esri_27Mcr_2.ttf',
#  'esri_29.ttf',
#  'esri_29.ttf',
#  'esri_3.ttf',
#  'esri_3.ttf',
#  'esri_30s.ttf',
#  'esri_30s.ttf',
#  'esri_33.ttf',
#  'esri_33.ttf',
#  'esri_34.ttf',
#  'esri_34.ttf',
#  'esri_375.ttf',
#  'esri_375.ttf',
#  'esri_376.ttf',
#  'esri_376.ttf',
#  'esri_377.ttf',
#  'esri_377.ttf',
#  'esri_39.ttf',
#  'esri_39.ttf',
#  'esri_4.ttf',
#  'esri_4.ttf',
#  'esri_40.ttf',
#  'esri_40.ttf',
#  'esri_400.ttf',
#  'esri_400.ttf',
#  'esri_405.ttf',
#  'esri_405.ttf',
#  'esri_406.ttf',
#  'esri_406.ttf',
#  'esri_44.ttf',
#  'esri_44.ttf',
#  'esri_47.ttf',
#  'esri_47.ttf',
#  'esri_48.ttf',
#  'esri_48.ttf',
#  'esri_49.ttf',
#  'esri_49.ttf',
#  'esri_5.ttf',
#  'esri_5.ttf',
#  'esri_500.ttf',
#  'esri_500.ttf',
#  'esri_651.ttf',
#  'esri_651.ttf',
#  'esri_652.ttf',
#  'esri_652.ttf',
#  'esri_7.ttf',
#  'esri_7.ttf',
#  'esri_730.ttf',
#  'esri_730.ttf',
#  'esri_8.ttf',
#  'esri_8.ttf',
#  'esri_800.ttf',
#  'esri_800.ttf',
#  'esri_801.ttf',
#  'esri_801.ttf',
#  'esri_802.ttf',
#  'esri_802.ttf',
#  'esri_803.ttf',
#  'esri_803.ttf',
#  'esri_804.ttf',
#  'esri_804.ttf',
#  'esri_832.ttf',
#  'esri_832.ttf',
#  'esri_837.ttf',
#  'esri_837.ttf',
#  'esri_9.ttf',
#  'esri_9.ttf',
#  'euclid.ttf',
#  'euclid_01.ttf',
#  'euclid_02.ttf',
#  'euclid_02.ttf',
#  'euclidb.ttf',
#  'euclidb_01.ttf',
#  'euclidb_02.ttf',
#  'euclidb_02.ttf',
#  'euclidbi.ttf',
#  'euclidbi_01.ttf',
#  'euclidbi_02.ttf',
#  'euclidbi_02.ttf',
#  'euclidi.ttf',
#  'euclidi_01.ttf',
#  'euclidi_02.ttf',
#  'euclidi_02.ttf',
#  'eucsym.ttf',
#  'eucsym_01.ttf',
#  'eucsym_02.ttf',
#  'eucsym_02.ttf',
#  'eucsymb.ttf',
#  'eucsymb_01.ttf',
#  'eucsymb_02.ttf',
#  'eucsymb_02.ttf',
#  'eucsymbi.ttf',
#  'eucsymbi_01.ttf',
#  'eucsymbi_02.ttf',
#  'eucsymbi_02.ttf',
#  'eucsymi.ttf',
#  'eucsymi_01.ttf',
#  'eucsymi_02.ttf',
#  'eucsymi_02.ttf',
#  'euextra.ttf',
#  'euextra_01.ttf',
#  'euextra_02.ttf',
#  'euextra_02.ttf',
#  'euextrab.ttf',
#  'euextrab_01.ttf',
#  'euextrab_02.ttf',
#  'euextrab_02.ttf',
#  'eufrak.ttf',
#  'eufrak_01.ttf',
#  'eufrak_02.ttf',
#  'eufrak_02.ttf',
#  'eufrakb.ttf',
#  'eufrakb_01.ttf',
#  'eufrakb_02.ttf',
#  'eufrakb_02.ttf',
#  'eumat1.ttf',
#  'eumat1_01.ttf',
#  'eumat1_02.ttf',
#  'eumat1_02.ttf',
#  'eumat1b.ttf',
#  'eumat1b_01.ttf',
#  'eumat1b_02.ttf',
#  'eumat1b_02.ttf',
#  'eumat2.ttf',
#  'eumat2_01.ttf',
#  'eumat2_02.ttf',
#  'eumat2_02.ttf',
#  'eumat2b.ttf',
#  'eumat2b_01.ttf',
#  'eumat2b_02.ttf',
#  'eumat2b_02.ttf',
#  'fences_01.ttf',
#  'fences_02.ttf',
#  'fences_02.ttf',
#  'framd.ttf',
#  'framd.ttf',
#  'framdit.ttf',
#  'framdit.ttf',
#  'gadugi.ttf',
#  'gadugi.ttf',
#  'gadugib.ttf',
#  'gadugib.ttf',
#  'georgia.ttf',
#  'georgia.ttf',
#  'georgiab.ttf',
#  'georgiab.ttf',
#  'georgiai.ttf',
#  'georgiai.ttf',
#  'georgiaz.ttf',
#  'georgiaz.ttf',
#  'himalaya.ttf',
#  'himalaya.ttf',
#  'holomdl2.ttf',
#  'holomdl2.ttf',
#  'impact.ttf',
#  'impact.ttf',
#  'javatext.ttf',
#  'javatext.ttf',
#  'l_10646.ttf',
#  'l_10646.ttf',
#  'lucon.ttf',
#  'lucon.ttf',
#  'malgun.ttf',
#  'malgun.ttf',
#  'malgunbd.ttf',
#  'malgunbd.ttf',
#  'malgunsl.ttf',
#  'malgunsl.ttf',
#  'marlett.ttf',
#  'micross.ttf',
#  'micross.ttf',
#  'mingliub.ttc',
#  'mingliub.ttc',
#  'mmrtext.ttf',
#  'mmrtext.ttf',
#  'mmrtextb.ttf',
#  'mmrtextb.ttf',
#  'monbaiti.ttf',
#  'monbaiti.ttf',
#  'msgothic.ttc',
#  'msgothic.ttc',
#  'msjh.ttc',
#  'msjh.ttc',
#  'msjhbd.ttc',
#  'msjhbd.ttc',
#  'msjhl.ttc',
#  'msjhl.ttc',
#  'mstmc.ttf',
#  'msyh.ttc',
#  'msyh.ttc',
#  'msyhbd.ttc',
#  'msyhbd.ttc',
#  'msyhl.ttc',
#  'msyhl.ttc',
#  'msyi.ttf',
#  'msyi.ttf',
#  'mtextra_01.ttf',
#  'mtextra_02.ttf',
#  'mtextra_02.ttf',
#  'mvboli.ttf',
#  'mvboli.ttf',
#  'ntailu.ttf',
#  'ntailu.ttf',
#  'ntailub.ttf',
#  'ntailub.ttf',
#  'pala.ttf',
#  'pala.ttf',
#  'palab.ttf',
#  'palab.ttf',
#  'palabi.ttf',
#  'palabi.ttf',
#  'palai.ttf',
#  'palai.ttf',
#  'phagspa.ttf',
#  'phagspa.ttf',
#  'phagspab.ttf',
#  'phagspab.ttf',
#  'segmdl2.ttf',
#  'segmdl2.ttf',
#  'segoepr.ttf',
#  'segoepr.ttf',
#  'segoeprb.ttf',
#  'segoeprb.ttf',
#  'segoesc.ttf',
#  'segoesc.ttf',
#  'segoescb.ttf',
#  'segoescb.ttf',
#  'segoeui.ttf',
#  'segoeui.ttf',
#  'segoeuib.ttf',
#  'segoeuib.ttf',
#  'segoeuii.ttf',
#  'segoeuii.ttf',
#  'segoeuil.ttf',
#  'segoeuil.ttf',
#  'segoeuisl.ttf',
#  'segoeuisl.ttf',
#  'segoeuiz.ttf',
#  'segoeuiz.ttf',
#  'seguibl.ttf',
#  'seguibl.ttf',
#  'seguibli.ttf',
#  'seguibli.ttf',
#  'seguiemj.ttf',
#  'seguiemj.ttf',
#  'seguihis.ttf',
#  'seguihis.ttf',
#  'seguili.ttf',
#  'seguili.ttf',
#  'seguisb.ttf',
#  'seguisb.ttf',
#  'seguisbi.ttf',
#  'seguisbi.ttf',
#  'seguisli.ttf',
#  'seguisli.ttf',
#  'seguisym.ttf',
#  'seguisym.ttf',
#  'simfang.ttf',
#  'simfang.ttf',
#  'simhei.ttf',
#  'simhei.ttf',
#  'simkai.ttf',
#  'simkai.ttf',
#  'simsun.ttc',
#  'simsun.ttc',
#  'simsunb.ttf',
#  'simsunb.ttf',
#  'sylfaen.ttf',
#  'sylfaen.ttf',
#  'symbol.ttf',
#  'symbol.ttf',
#  'tahoma.ttf',
#  'tahoma.ttf',
#  'tahomabd.ttf',
#  'tahomabd.ttf',
#  'taile.ttf',
#  'taile.ttf',
#  'taileb.ttf',
#  'taileb.ttf',
#  'times.ttf',
#  'times.ttf',
#  'timesbd.ttf',
#  'timesbd.ttf',
#  'timesbi.ttf',
#  'timesbi.ttf',
#  'timesi.ttf',
#  'timesi.ttf',
#  'trebuc.ttf',
#  'trebuc.ttf',
#  'trebucbd.ttf',
#  'trebucbd.ttf',
#  'trebucbi.ttf',
#  'trebucbi.ttf',
#  'trebucit.ttf',
#  'trebucit.ttf',
#  'tt0003m_.ttf',
#  'tt0004m_.ttf',
#  'tt0005m_.ttf',
#  'tt0006m_.ttf',
#  'tt0011m_.ttf',
#  'tt0012m_.ttf',
#  'tt0013m_.ttf',
#  'tt0014m_.ttf',
#  'tt0419m_.ttf',
#  'tt0582m_.ttf',
#  'tt0583m_.ttf',
#  'tt0611m_.ttf',
#  'tt9830z_.ttf',
#  'tt9831z_.ttf',
#  'verdana.ttf',
#  'verdana.ttf',
#  'verdanab.ttf',
#  ...]

# %%
geemap.add_text_to_gif(
    in_gif,
    out_gif,
    xy=('5%', '5%'),
    text_sequence=1984,
    font_size=30,
    font_color='#0000ff',
    duration=100,
)
geemap.add_text_to_gif(
    out_gif,
    out_gif,
    xy=('30%', '85%'),
    text_sequence="Las Vegas",
    font_type="timesbd.ttf",
    font_size=30,
    font_color='black',
)
geemap.show_image(out_gif)
# Out:
# Output()

# %% [markdown]
# ## Create GIF from Earth Engine data
#
# This example was adapted from the Earth Engine JavaScript API Documentation [here](https://developers.google.com/earth-engine/ic_visualization#video_thumb).

# %% [markdown]
# ### Prepare for an ImageCollection

# %%
import ee
import geemap

ee.Initialize()

# Define an area of interest geometry with a global non-polar extent.
aoi = ee.Geometry.Polygon(
    [[[-179.0, 78.0], [-179.0, -58.0], [179.0, -58.0], [179.0, 78.0]]], None, False
)

# Import hourly predicted temperature image collection for northern winter
# solstice. Note that predictions extend for 384 hours; limit the collection
# to the first 24 hours.
tempCol = (
    ee.ImageCollection('NOAA/GFS0P25')
    .filterDate('2018-12-22', '2018-12-23')
    .limit(24)
    .select('temperature_2m_above_ground')
)

# Define arguments for animation function parameters.
videoArgs = {
    'dimensions': 768,
    'region': aoi,
    'framesPerSecond': 10,
    'crs': 'EPSG:3857',
    'min': -40.0,
    'max': 35.0,
    'palette': ['blue', 'purple', 'cyan', 'green', 'yellow', 'red'],
}
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\httplib2shim\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#     139         try:
# --> 140             urllib3_response = self.pool.request(
#     141                 method,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     385             # Disabled, indicate to re-raise the error.
# --> 386             raise six.reraise(type(error), error, _stacktrace)
#     387
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000002138DEB8130>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# <ipython-input-15-a4aaeb62b942> in <module>
#       2 import geemap
#       3
# ----> 4 ee.Initialize()
#       5
#       6 # Define an area of interest geometry with a global non-polar extent.
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\ee\__init__.py in Initialize(credentials, opt_url, cloud_api_key, http_transport, project)
#     126   if credentials == 'persistent':
#     127     credentials = data.get_persistent_credentials()
# --> 128   data.initialize(
#     129       credentials=credentials,
#     130       api_base_url=(opt_url + '/api' if opt_url else None),
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\ee\data.py in initialize(credentials, api_base_url, tile_base_url, cloud_api_base_url, cloud_api_key, project, http_transport)
#     199   _http_transport = http_transport
#     200
# --> 201   _install_cloud_api_resource()
#     202
#     203   if project is not None:
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\ee\data.py in _install_cloud_api_resource()
#     258
#     259   timeout = (_deadline_ms / 1000.0) or None
# --> 260   _cloud_api_resource = _cloud_api_utils.build_cloud_resource(
#     261       _cloud_api_base_url,
#     262       credentials=_credentials,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\ee\_cloud_api_utils.py in build_cloud_resource(api_base_url, api_key, credentials, timeout, headers_supplier, response_inspector, http_transport, raw)
#     159     pass  # Handle fallback case outside except block, for cleaner stack traces.
#     160   if resource is None:
# --> 161     resource = build()
#     162   resource._baseUrl = api_base_url
#     163   return resource
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\ee\_cloud_api_utils.py in build(**kwargs)
#     139
#     140   def build(**kwargs):
# --> 141     return discovery.build(
#     142         'earthengine',
#     143         VERSION,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\discovery.py in build(serviceName, version, http, discoveryServiceUrl, developerKey, model, requestBuilder, credentials, cache_discovery, cache, client_options, adc_cert_path, adc_key_path, num_retries)
#     268
#     269         try:
# --> 270             content = _retrieve_discovery_doc(
#     271                 requested_url,
#     272                 discovery_http,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\discovery.py in _retrieve_discovery_doc(url, http, cache_discovery, cache, developerKey, num_retries)
#     374     # Note that it will already raise an error if we don't get a 2xx response
#     375     req = HttpRequest(http, HttpRequest.null_postproc, actual_url)
# --> 376     resp, content = req.execute(num_retries=num_retries)
#     377
#     378     try:
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     898
#     899         # Handle retries for server-side errors.
# --> 900         resp, content = _retry_request(
#     901             http,
#     902             num_retries,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     202         if exception:
#     203             if retry_num == num_retries:
# --> 204                 raise exception
#     205             else:
#     206                 continue
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\googleapiclient\http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     175         try:
#     176             exception = None
# --> 177             resp, content = http.request(uri, method, *args, **kwargs)
#     178         # Retry on SSL errors and socket timeout errors.
#     179         except _ssl_SSLError as ssl_error:
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\google_auth_httplib2.py in request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     207         request_headers = headers.copy() if headers is not None else {}
#     208
# --> 209         self.credentials.before_request(self._request, method, uri, request_headers)
#     210
#     211         # Check if the body is a file-like stream, and if so, save the body
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\google\auth\credentials.py in before_request(self, request, method, url, headers)
#     131         # the http request.)
#     132         if not self.valid:
# --> 133             self.refresh(request)
#     134         self.apply(headers)
#     135
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\google\oauth2\credentials.py in refresh(self, request)
#     291             grant_response,
#     292             rapt_token,
# --> 293         ) = reauth.refresh_grant(
#     294             request,
#     295             self._token_uri,
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\google\oauth2\reauth.py in refresh_grant(request, token_uri, refresh_token, client_id, client_secret, scopes, rapt_token)
#     316         body["rapt"] = rapt_token
#     317
# --> 318     response_status_ok, response_data = _client._token_endpoint_request_no_throw(
#     319         request, token_uri, body
#     320     )
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\google\oauth2\_client.py in _token_endpoint_request_no_throw(request, token_uri, body, access_token, use_json)
#     113     # occurs.
#     114     while True:
# --> 115         response = request(method="POST", url=token_uri, headers=headers, body=body)
#     116         response_body = (
#     117             response.data.decode("utf-8")
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\google_auth_httplib2.py in __call__(self, url, method, body, headers, timeout, **kwargs)
#     117         try:
#     118             _LOGGER.debug("Making request: %s %s", method, url)
# --> 119             response, data = self.http.request(
#     120                 url, method=method, body=body, headers=headers, **kwargs
#     121             )
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\httplib2\__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1699                     content = b""
#    1700                 else:
# -> 1701                     (response, content) = self._request(
#    1702                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703                     )
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\httplib2\__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1419             auth.request(method, request_uri, headers, body)
#    1420
# -> 1421         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1422
#    1423         if auth:
#
# D:\software_code\Anaconda\envs\pytorch\lib\site-packages\httplib2shim\__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#     152
#     153         except Exception as e:
# --> 154             raise _map_exception(e)
#     155
#     156         return response, content
#
# timeout: timed out

# %% [markdown]
# ### Save the GIF to local drive

# %%
saved_gif = os.path.join(os.path.expanduser('~'), 'Downloads/temperature.gif')
geemap.download_ee_video(tempCol, videoArgs, saved_gif)

# %%
geemap.show_image(saved_gif)

# %% [markdown]
# ### Generate an hourly text sequence

# %%
text = [str(n).zfill(2) + ":00" for n in range(0, 24)]
print(text)

# %% [markdown]
# ### Add text to GIF

# %%
out_gif = os.path.join(os.path.expanduser('~'), 'Downloads/output2.gif')

# %%
geemap.add_text_to_gif(
    saved_gif,
    out_gif,
    xy=('3%', '5%'),
    text_sequence=text,
    font_size=30,
    font_color='#ffffff',
)

# %%
geemap.add_text_to_gif(
    out_gif,
    out_gif,
    xy=('32%', '92%'),
    text_sequence='NOAA GFS Hourly Temperature',
    font_color='white',
)

# %%
geemap.show_image(out_gif)
